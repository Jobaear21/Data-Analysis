# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('D:/Machine learning/Practices/Data sets/Hotel_fans_from_Facebook.csv')

# %%
data.head()
# Out:
#   Average New Hotel Fan Growth From Facebook        Unnamed: 1    Unnamed: 2  \
# 0                                       CITY  NUMBER OF HOTELS  AVG BEDROOMS
# 1                                      Paris               292            94
# 2                                     London               180           172
# 3                                   New York               150           310
# 4                                     Phuket               132           166
#
#   Unnamed: 3    Unnamed: 4
# 0  AVG STARS  AVG NEW FANS
# 1        3.8             4
# 2        4.2            13
# 3        4.2            32
# 4        4.4            58

# %%
data.columns = ['City','Number Of Hotels','AVG Bedrooms','AVG Stars','AVG New Fans']

# %%
data.head()
# Out:
#        City  Number Of Hotels  AVG Bedrooms  AVG Stars  AVG New Fans
# 0      CITY  NUMBER OF HOTELS  AVG BEDROOMS  AVG STARS  AVG NEW FANS
# 1     Paris               292            94        3.8             4
# 2    London               180           172        4.2            13
# 3  New York               150           310        4.2            32
# 4    Phuket               132           166        4.4            58

# %%
data = data.drop(labels=0,axis=0)
data.head()
# Out:
#        City Number Of Hotels AVG Bedrooms AVG Stars AVG New Fans
# 1     Paris              292           94       3.8            4
# 2    London              180          172       4.2           13
# 3  New York              150          310       4.2           32
# 4    Phuket              132          166       4.4           58
# 5     Milan              119          107         4            5

# %%
data['AVG New Fans'].min()
# Out:
# '10'

# %%
data
# Out:
#               City Number Of Hotels AVG Bedrooms AVG Stars AVG New Fans
# 1            Paris              292           94       3.8            4
# 2           London              180          172       4.2           13
# 3         New York              150          310       4.2           32
# 4           Phuket              132          166       4.4           58
# 5            Milan              119          107         4            5
# 6            Dubai              113          330       4.6           98
# 7          Bangkok              103          280       4.4           57
# 8        Hong Kong              101          405       4.2           34
# 9       Swiss Alps              101           63       4.4            3
# 10       Caribbean               97          144       4.4           94
# 11   South Pacific               88           68       4.3           42
# 12            Rome               88           82       4.3            7
# ...
